# %%
# (1) 데이터 읽기
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings       
warnings.filterwarnings("ignore")
import os
os.chdir('C:/Users/urse/Documents/카카오톡 받은 파일/')

# 군집 
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.8,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 9개 0,-1 제거
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.45,min_samples= 100).csv', engine='python', encoding='euc-kr')

# 군집 33개 1, -1 제거
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.45,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 55개 1, -1 제거 - iteration 3
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.35,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 49개 1, -1 제거 - iteration 4
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.3,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 95개 1, -1 제거 - iteration 5
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.3,min_samples= 20).csv', engine='python', encoding='euc-kr')

# 군집 208개 1, -1 제거 - iteration 6
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/clusters_completed(eps=0.3,min_samples= 10).csv', engine='python', encoding='euc-kr')

# 군집 198개 -1 제거 - iteration 7 - SCAILING X 
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.3,min_samples= 20).csv', engine='python', encoding='euc-kr')

# 군집 105개 -1 0 제거 행 9281개 - iteration 8 - SCAILING O 
### data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.3,min_samples= 20) (1).csv', engine='python', encoding='euc-kr')

# 군집 83개  1, -1 제거 행 11190개 - iteration 9
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.35,min_samples= 20).csv', engine='python', encoding='euc-kr')

# 군집 82개  2, -1 제거 행  - iteration 10
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.3,min_samples= 10).csv', engine='python', encoding='euc-kr')

# 군집 57개 0 -1제거 7919행  - iteration 11
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.32,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 개 2 -1제거 행  - iteration 12
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.8,min_samples= 5).csv', engine='python', encoding='euc-kr')

# 군집 152개 2 -1제거 행  - iteration 13
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.4,min_samples= 5).csv', engine='python', encoding='euc-kr')

# 군집 67개 1 -1제거 16864행  - iteration 14
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.9,min_samples= 30).csv', engine='python', encoding='euc-kr')

# 군집 37개 1 -1제거 14527행  - iteration 15
# data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/final(eps=0.9,min_samples= 50).csv', engine='python', encoding='euc-kr')

# final !!! 최종
# 군집 - iteration 20
data = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/real_final.csv', engine='python', encoding='euc-kr')

iteration = 20
print(data.shape)
print('로딩완료')
data.head()
# Out:
# (2280, 29)
# 로딩완료
#    Unnamed: 0              x              y  소로  중로2류  소로1류  소로3류  중로3류  소로2류  \
# 0          62  193476.977258  544597.360844  23     0     2     0     0     1
# 1          85  197625.062053  542747.306679  15     0     0     3     0     0
# 2          96  197575.340296  542736.746492  17     0     0     4     0     0
# 3         106  193632.956824  544262.380740  15     0     0     0     0     4
# 4         117  197701.837971  542678.964872  18     0     0     0     0     0
#
#    중로1류  ...  market  binary_accident  old/building  child/building  \
# 0     0  ...     0.0              0.0      0.000000        0.007722
# 1     0  ...     1.0              0.0      0.000000        0.005376
# 2     0  ...     1.0              0.0      0.008511        0.008511
# 3     0  ...     0.0              1.0      0.000000        0.004831
# 4     0  ...     2.0              1.0      0.000000        0.005650
#
#    output_values         X좌표        Y좌표  clusters  value_mean  rank
# ...

# %%
# (2) 기타 데이터 로드
# 노인 교통사고지역 로딩
old_accident = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/old_accident.csv', engine='python', encoding='euc-kr')
print(old_accident.shape)

# 노인보호구역
old = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/노인보호구역.csv', engine='python', encoding='euc-kr')
print(old.shape)
# Out:
# (36, 7)
# (7, 17)

# %%
# (2) 기타 데이터 로드
# 전통시장
market = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/서울특별시_동작구_전통시장_20190527.csv', engine='python', encoding='euc-kr')
print(market.shape)

# 어린이보호구역
child = pd.read_csv('C:/Users/urse/Documents/카카오톡 받은 파일/동작구_어린이보호구역.csv', engine='python', encoding='euc-kr')
print(child.shape)
# Out:
# (13, 16)
# (61, 12)

# %%
"""
# (x) (3) 종속변수들 - 사고가 날 것이라고 예상한 지역 binary_accident == 1
map_accident_1 = data[data['binary_accident']==1].copy()
print(map_accident_1.shape)

map_accident_1[['X좌표','Y좌표']]= map_accident_1.apply(transform_utmk_to_w84, axis=1)
print('변환완료')
map_accident_1.head()
"""

# %%
"""
# (3) 좌표 변환 함수 정의
from pyproj import Proj, transform
# WGS1984
proj_WGS84 = Proj(init='epsg:4326') # Wgs84 경도/위도, GPS사용 전지구 좌표

# proj_UTMK = Proj(init='epsg:5186') # UTM-K(Bassel) 도로명주소 지도 사용 중
proj_UTMK = Proj(init='epsg:5186') # kt 데이터

def transform_utmk_to_w84(df):
    return pd.Series(transform(proj_UTMK,proj_WGS84,df['x'],df['y']),index=['x','y'])

map_cluster[['X좌표','Y좌표']]= map_cluster.apply(transform_utmk_to_w84, axis=1)
print(map_cluster.shape)
"""

# %%
# (3) 군집 10000개 넘는 cluster들은 제거 -> 비사고 지역끼리 묶인 셀들 !
# (3) 군집 제거 (1 ~ -1 제거)
map_cluster = data[data['clusters']!=1]
print(map_cluster.shape)
map_cluster = map_cluster[map_cluster['clusters']!=-1]
print(map_cluster.shape)
# Out:
# (22969, 27)
# (14527, 27)

# %%
# (3) 군집 제거 (2, 1, -1 제거)
map_cluster = data[data['clusters']!=1]
print(map_cluster.shape)
map_cluster = map_cluster[map_cluster['clusters']!=-1]
print(map_cluster.shape)
map_cluster = map_cluster[map_cluster['clusters']!=2]
print(map_cluster.shape)
# Out:
# (43672, 24)
# (37149, 24)
# (9281, 24)

# %%
# (3) 군집제거 2랑 -1 제거
map_cluster = map_cluster[map_cluster['clusters']!=-1]
print(map_cluster.shape)
map_cluster = map_cluster[map_cluster['clusters']!=2]
print(map_cluster.shape)
# Out:
# (36789, 27)
# (9540, 27)

# %%
# (3) 군집 제거 (-1 ~ 0 제거)
map_cluster = data[data['clusters']>0]
print(map_cluster.shape)
# Out:
# (9849, 27)

# %%
# (3) 군집 제거 (-1 제거)
map_cluster = data[data['clusters']!=-1]
print(map_cluster.shape)
# Out:
# (18923, 27)

# %%
# (3) 군집 제거 (2 제거)
map_cluster = data[data['clusters']!=2]
print(map_cluster.shape)
# Out:
# (18532, 27)

# %%
# (4) 군집갯수 확인
# sharp - value 값들로 rank 점수 계산 한 것 이용
map_cluster = data.copy()
cluster1 = map_cluster['rank'].value_counts()
print(len(cluster1))
print(cluster1)
ls = list(cluster1.index)
# Out:
# 7
# 6.0    449
# 5.0    437
# 7.0    415
# 3.0    407
# 4.0    272
# 2.0    228
# 1.0     72
# Name: rank, dtype: int64

# %%
# (5) 동작구 경계지도 read - .json 파일
import folium
from folium.plugins import FastMarkerCluster

import json
with open('./dongjak_municipalities_geo.json',mode='rt',encoding='utf-8') as f:
    geo = json.loads(f.read())
    f.close()
print('파일읽기 완료')
# Out:
# 파일읽기 완료

# %%
# 최종 color
color_data = ['#F2563C', '#ED8C2B', '#EBC447', '#8AAE92', '#5186F1', '#42638A', '#957CBA']

# %%
# (7) data1 - cluster1 - 모든 좌표 색 동일

center = [map_cluster['Y좌표'].mean(), map_cluster['X좌표'].mean()]
tile_map = 'OpenStreetMap' 
map = folium.Map(location = center, tiles=tile_map, zoom_start=14)
# TILES OpenStreetMap / mapquestopen / MapQuest Open Aerial / Mapbox Bright
# TILES stamenterrain / stamenwatercolor / cartodbpositron

count = 0
remove_count = 0
for i in map_cluster.index:
    if map_cluster.loc[i, 'rank'] ==  ls[0]: # 
        icon_color = color_data[0]
    elif map_cluster.loc[i, 'rank'] == ls[1] : # 
        icon_color = color_data[1]
    elif map_cluster.loc[i, 'rank'] == ls[2]: # 
        icon_color = color_data[2]
    elif map_cluster.loc[i, 'rank'] == ls[3] : # 
        icon_color = color_data[3]
    elif map_cluster.loc[i, 'rank'] == ls[4] : # 
        icon_color = color_data[4]
    elif map_cluster.loc[i, 'rank'] == ls[5] : #
        icon_color = color_data[5]
    elif map_cluster.loc[i, 'rank'] == ls[6] : # 
        icon_color = color_data[6]   

    else:
        icon_color = '#000000'
        remove_count+=1
    if icon_color != '#000000':
        folium.CircleMarker(
            location = [map_cluster.loc[i,'Y좌표'], map_cluster.loc[i,'X좌표']],
            radius = 3, # 원의 크기 (2가 마지노선)
            color=icon_color, # 테두리색
        ).add_to(map)

# 노인 보호구역
for i in old.index:
    folium.CircleMarker(
        location = [old.loc[i,'위도'], old.loc[i,'경도']],
        radius = 10,    
        color='#F3B15A'# 테두리색 - 노란색
    ).add_to(map)
    #print([old.loc[i,'경도'], old.loc[i,'위도']])


# 노인 교통사고
for i in old_accident.index:
    folium.CircleMarker(
        location = [old_accident.loc[i, '위도'], old_accident.loc[i, '경도']],
        radius = 15,
        color = '#FFFF00'
    ).add_to(map)

# market
for i in market.index:
    folium.CircleMarker(
        location = [market.loc[i, '위도'], market.loc[i, '경도']],
        radius = 15,
        color = '#0000FF'
    ).add_to(map)


# child
for i in child.index:
    folium.CircleMarker(
        location = [child.loc[i, '위도'], child.loc[i, '경도']],
        radius = 15,
        color = '#00FF00'
    ).add_to(map)
    
# 동작구 형태지도 출력
folium.GeoJson(
    geo,
    name='dongjak_municipalities',
).add_to(map)

# 맵 저장
map.save('final_map' + str(iteration) + '.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
